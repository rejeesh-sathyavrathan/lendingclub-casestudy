# %%
#Load the libraryss
import warnings
warnings.filterwarnings("ignore")
import pandas as pd #To work with dataset
import numpy as np #Math library
import seaborn as sns #Graph library that use matplot in background
import matplotlib.pyplot as plt #to plot some parameters in seaborn
# %matplotlib inline

# %% [markdown]
# # 1. Data Understanding

# %% [markdown]
# ## 1.1 Import data

# %%
loan_data = pd.read_csv("loan.csv")
loan_data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                NaN            NaN               NaN                  0.0
# 1                NaN            NaN               NaN                  0.0
# 2                NaN            NaN               NaN                  0.0
# 3                NaN            NaN               NaN                  0.0
# 4                NaN            NaN               NaN                  0.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       0.0             NaN               NaN            NaN
# 1       0.0             NaN               NaN            NaN
# 2       0.0             NaN               NaN            NaN
# 3       0.0             NaN               NaN            NaN
# 4       0.0             NaN               NaN            NaN
#
#   total_il_high_credit_limit
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 111 columns]

# %% [markdown]
# ## 1.2 Analyse columns

# %%
loan_data.shape
# Out:
# (39717, 111)

# %%
# loan_data data frame contains 111 columns. Get column names and split them into buckets of 20, so that column info can be printed
column_names = loan_data.columns

# %%
print(loan_data[column_names[0:20]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  object
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   sub_grade            39717 non-null  object
#  10  emp_title            37258 non-null  object
#  11  emp_length           38642 non-null  object
#  12  home_ownership       39717 non-null  object
#  13  annual_inc           39717 non-null  float64
#  14  verification_status  39717 non-null  object
#  15  issue_d              39717 non-null  object
#  16  loan_status          39717 non-null  object
#  17  pymnt_plan           39717 non-null  object
#  18  url                  39717 non-null  object
#  19  desc                 26777 non-null  object
# dtypes: float64(3), int64(4), object(13)
# memory usage: 6.1+ MB
# None

# %%
print(loan_data[column_names[20:40]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   purpose                 39717 non-null  object
#  1   title                   39706 non-null  object
#  2   zip_code                39717 non-null  object
#  3   addr_state              39717 non-null  object
#  4   dti                     39717 non-null  float64
#  5   delinq_2yrs             39717 non-null  int64
#  6   earliest_cr_line        39717 non-null  object
#  7   inq_last_6mths          39717 non-null  int64
#  8   mths_since_last_delinq  14035 non-null  float64
#  9   mths_since_last_record  2786 non-null   float64
#  10  open_acc                39717 non-null  int64
#  11  pub_rec                 39717 non-null  int64
#  12  revol_bal               39717 non-null  int64
#  13  revol_util              39667 non-null  object
#  14  total_acc               39717 non-null  int64
#  15  initial_list_status     39717 non-null  object
#  16  out_prncp               39717 non-null  float64
#  17  out_prncp_inv           39717 non-null  float64
#  18  total_pymnt             39717 non-null  float64
#  19  total_pymnt_inv         39717 non-null  float64
# dtypes: float64(7), int64(6), object(7)
# memory usage: 6.1+ MB
# None

# %%
print(loan_data[column_names[40:60]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   total_rec_prncp              39717 non-null  float64
#  1   total_rec_int                39717 non-null  float64
#  2   total_rec_late_fee           39717 non-null  float64
#  3   recoveries                   39717 non-null  float64
#  4   collection_recovery_fee      39717 non-null  float64
#  5   last_pymnt_d                 39646 non-null  object
#  6   last_pymnt_amnt              39717 non-null  float64
#  7   next_pymnt_d                 1140 non-null   object
#  8   last_credit_pull_d           39715 non-null  object
#  9   collections_12_mths_ex_med   39661 non-null  float64
#  10  mths_since_last_major_derog  0 non-null      float64
#  11  policy_code                  39717 non-null  int64
#  12  application_type             39717 non-null  object
#  13  annual_inc_joint             0 non-null      float64
#  14  dti_joint                    0 non-null      float64
#  15  verification_status_joint    0 non-null      float64
#  16  acc_now_delinq               39717 non-null  int64
#  17  tot_coll_amt                 0 non-null      float64
#  18  tot_cur_bal                  0 non-null      float64
#  19  open_acc_6m                  0 non-null      float64
# dtypes: float64(14), int64(2), object(4)
# memory usage: 6.1+ MB
# None

# %%
print(loan_data[column_names[60:80]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   open_il_6m                0 non-null      float64
#  1   open_il_12m               0 non-null      float64
#  2   open_il_24m               0 non-null      float64
#  3   mths_since_rcnt_il        0 non-null      float64
#  4   total_bal_il              0 non-null      float64
#  5   il_util                   0 non-null      float64
#  6   open_rv_12m               0 non-null      float64
#  7   open_rv_24m               0 non-null      float64
#  8   max_bal_bc                0 non-null      float64
#  9   all_util                  0 non-null      float64
#  10  total_rev_hi_lim          0 non-null      float64
#  11  inq_fi                    0 non-null      float64
#  12  total_cu_tl               0 non-null      float64
#  13  inq_last_12m              0 non-null      float64
#  14  acc_open_past_24mths      0 non-null      float64
#  15  avg_cur_bal               0 non-null      float64
#  16  bc_open_to_buy            0 non-null      float64
#  17  bc_util                   0 non-null      float64
#  18  chargeoff_within_12_mths  39661 non-null  float64
#  19  delinq_amnt               39717 non-null  int64
# dtypes: float64(19), int64(1)
# memory usage: 6.1 MB
# None

# %%
print(loan_data[column_names[80:100]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   mo_sin_old_il_acct              0 non-null      float64
#  1   mo_sin_old_rev_tl_op            0 non-null      float64
#  2   mo_sin_rcnt_rev_tl_op           0 non-null      float64
#  3   mo_sin_rcnt_tl                  0 non-null      float64
#  4   mort_acc                        0 non-null      float64
#  5   mths_since_recent_bc            0 non-null      float64
#  6   mths_since_recent_bc_dlq        0 non-null      float64
#  7   mths_since_recent_inq           0 non-null      float64
#  8   mths_since_recent_revol_delinq  0 non-null      float64
#  9   num_accts_ever_120_pd           0 non-null      float64
#  10  num_actv_bc_tl                  0 non-null      float64
#  11  num_actv_rev_tl                 0 non-null      float64
#  12  num_bc_sats                     0 non-null      float64
#  13  num_bc_tl                       0 non-null      float64
#  14  num_il_tl                       0 non-null      float64
#  15  num_op_rev_tl                   0 non-null      float64
#  16  num_rev_accts                   0 non-null      float64
#  17  num_rev_tl_bal_gt_0             0 non-null      float64
#  18  num_sats                        0 non-null      float64
#  19  num_tl_120dpd_2m                0 non-null      float64
# dtypes: float64(20)
# memory usage: 6.1 MB
# None

# %%
print(loan_data[column_names[100:]].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   num_tl_30dpd                0 non-null      float64
#  1   num_tl_90g_dpd_24m          0 non-null      float64
#  2   num_tl_op_past_12m          0 non-null      float64
#  3   pct_tl_nvr_dlq              0 non-null      float64
#  4   percent_bc_gt_75            0 non-null      float64
#  5   pub_rec_bankruptcies        39020 non-null  float64
#  6   tax_liens                   39678 non-null  float64
#  7   tot_hi_cred_lim             0 non-null      float64
#  8   total_bal_ex_mort           0 non-null      float64
#  9   total_bc_limit              0 non-null      float64
#  10  total_il_high_credit_limit  0 non-null      float64
# dtypes: float64(11)
# memory usage: 3.3 MB
# None

# %%
# print numerical column stats
loan_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#         delinq_2yrs  inq_last_6mths  ...  num_tl_90g_dpd_24m  \
# count  39717.000000    39717.000000  ...                 0.0
# mean       0.146512        0.869200  ...                 NaN
# std        0.491812        1.070219  ...                 NaN
# min        0.000000        0.000000  ...                 NaN
# 25%        0.000000        0.000000  ...                 NaN
# 50%        0.000000        1.000000  ...                 NaN
# 75%        0.000000        1.000000  ...                 NaN
# max       11.000000        8.000000  ...                 NaN
#
#        num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# count                 0.0             0.0               0.0
# mean                  NaN             NaN               NaN
# std                   NaN             NaN               NaN
# min                   NaN             NaN               NaN
# 25%                   NaN             NaN               NaN
# 50%                   NaN             NaN               NaN
# 75%                   NaN             NaN               NaN
# max                   NaN             NaN               NaN
#
#        pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# count          39020.000000    39678.0              0.0                0.0
# mean               0.043260        0.0              NaN                NaN
# std                0.204324        0.0              NaN                NaN
# min                0.000000        0.0              NaN                NaN
# 25%                0.000000        0.0              NaN                NaN
# 50%                0.000000        0.0              NaN                NaN
# 75%                0.000000        0.0              NaN                NaN
# max                2.000000        0.0              NaN                NaN
#
#        total_bc_limit  total_il_high_credit_limit
# count             0.0                         0.0
# mean              NaN                         NaN
# std               NaN                         NaN
# min               NaN                         NaN
# 25%               NaN                         NaN
# 50%               NaN                         NaN
# 75%               NaN                         NaN
# max               NaN                         NaN
#
# [8 rows x 87 columns]

# %% [markdown]
# # 2. Data Cleaning

# %% [markdown]
# ## 2.1 Cleanup null values
# loan_data.info() shows many columns contains zero non-null values, means all values are null. Some columns has very few non-null values which doesn't make sense in this analysis. Columns with a null precentage more than 70 can be removed from the data frame.

# %%
# Get column names where null percent is above 70.
cols_with_null_70_or_more = ((loan_data.isna().sum()/len(loan_data)) * 100 > 70)
column_names_with_null_70_or_more = cols_with_null_70_or_more[cols_with_null_70_or_more == True].index

# %%
# drop columns where null percent is above 70. 
loan_data.drop(columns=column_names_with_null_70_or_more, inplace=True)

# %%
# verify column count after removing null columns
loan_data.shape
# Out:
# (39717, 55)

# %% [markdown]
# ## 2.2 Remove Customer behavior variables
# Customer behavior variables are not available at the time of loan application, and thus they cannot be used as predictors for credit approval. Below mentioned customer behavior columns can be removed.
#  - 'delinq_2yrs',
#  - 'earliest_cr_line',
#  - 'inq_last_6mths',
#  - 'open_acc',
#  - 'pub_rec',
#  - 'revol_bal',
#  - 'revol_util',
#  - 'total_acc',
#  - 'out_prncp',
#  - 'out_prncp_inv',
#  - 'total_pymnt',
#  - 'total_pymnt_inv',
#  - 'total_rec_prncp',
#  - 'total_rec_int',
#  - 'total_rec_late_fee',
#  - 'recoveries',
#  - 'collection_recovery_fee',
#  - 'last_pymnt_d',
#  - 'last_pymnt_amnt',
#  - 'last_credit_pull_d',
#  - 'application_type'

# %%
customer_behavior_cols = ['delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc','pub_rec','revol_bal','revol_util','total_acc','out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','last_credit_pull_d','application_type', 'emp_title']
loan_data.drop(columns=customer_behavior_cols, inplace=True)

# %%
# verify column count after removing customer behavior columns
loan_data.shape
# Out:
# (39717, 33)

# %% [markdown]
# ## 2.3 Remove columns with single value
# Columns with single value doesnt impact the analysis. These columns can be removed.

# %%
# use loan_data.describe() to view numerical column stats. For numerical columns with single value, min() and max() will be same.
loan_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#        mths_since_last_delinq  collections_12_mths_ex_med  policy_code  \
# count            14035.000000                     39661.0      39717.0
# mean                35.900962                         0.0          1.0
# std                 22.020060                         0.0          0.0
# min                  0.000000                         0.0          1.0
# 25%                 18.000000                         0.0          1.0
# 50%                 34.000000                         0.0          1.0
# 75%                 52.000000                         0.0          1.0
# max                120.000000                         0.0          1.0
#
#        acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# count         39717.0                   39661.0      39717.0
# mean              0.0                       0.0          0.0
# std               0.0                       0.0          0.0
# min               0.0                       0.0          0.0
# 25%               0.0                       0.0          0.0
# 50%               0.0                       0.0          0.0
# 75%               0.0                       0.0          0.0
# max               0.0                       0.0          0.0
#
#        pub_rec_bankruptcies  tax_liens
# count          39020.000000    39678.0
# mean               0.043260        0.0
# std                0.204324        0.0
# min                0.000000        0.0
# 25%                0.000000        0.0
# 50%                0.000000        0.0
# 75%                0.000000        0.0
# max                2.000000        0.0

# %%
# Get the column names where min and max are same and drop them.
cols_where_value_is_same = loan_data.min() == loan_data.max()
column_names_where_value_is_same = cols_where_value_is_same[cols_where_value_is_same == True].index

loan_data.drop(columns=column_names_where_value_is_same, inplace=True)

# %%
# verify column count after removing columns with single value
loan_data.shape
# Out:
# (39717, 25)

# %%
# verify numerical stats after removing columns with single value
loan_data.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# 50%        8975.000000    280.220000  5.900000e+04     13.400000
# 75%       14400.000000    430.780000  8.230000e+04     18.600000
# max       35000.000000   1305.190000  6.000000e+06     29.990000
#
#        mths_since_last_delinq  pub_rec_bankruptcies
# count            14035.000000          39020.000000
# mean                35.900962              0.043260
# std                 22.020060              0.204324
# min                  0.000000              0.000000
# 25%                 18.000000              0.000000
# 50%                 34.000000              0.000000
# 75%                 52.000000              0.000000
# max                120.000000              2.000000

# %% [markdown]
# # 3 Data Analysis
# identify predictors of default so that at the time of loan application, we can use those variables for approval/rejection of the loan

# %% [markdown]
# ## 3.1 Analyse all columns
# Analyse all remianing columns using value_counts() to understand different values

# %%
# print all column names
print(loan_data.columns)
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'loan_status', 'url', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'mths_since_last_delinq', 'pub_rec_bankruptcies'],
#       dtype='object')

# %% [markdown]
# ### 3.1.1 id

# %%
(loan_data.id.value_counts() > 1).sum()
# Out:
# 0

# %%
# This is a unique id and doesn't impact the analysis. So this column can be removed
loan_data.drop(columns=['id'], inplace=True)

# %% [markdown]
# ### 3.1.2 member_id

# %%
(loan_data.member_id.value_counts() > 1).sum()
# Out:
# 0

# %%
# This is a unique id and doesn't impact the analysis. So this column can be removed
loan_data.drop(columns=['member_id'], inplace=True)

# %% [markdown]
# ### 3.1.3 issue_d

# %%
# Dropping issue_d as we are not planning to derive any month/year wise recommendation  
loan_data.drop(columns=['issue_d'], inplace=True)

# %% [markdown]
# ### 3.1.4 loan_amnt

# %%
loan_data.loan_amnt.value_counts()
# Out:
# 10000    2833
# 12000    2334
# 5000     2051
# 6000     1908
# 15000    1895
#          ...
# 22875       1
# 8175        1
# 19475       1
# 21225       1
# 22550       1
# Name: loan_amnt, Length: 885, dtype: int64

# %% [markdown]
# ### 3.1.5 funded_amnt

# %%
loan_data.funded_amnt.value_counts()
# Out:
# 10000    2741
# 12000    2244
# 5000     2040
# 6000     1898
# 15000    1784
#          ...
# 26250       1
# 24725       1
# 31750       1
# 22625       1
# 22350       1
# Name: funded_amnt, Length: 1041, dtype: int64

# %% [markdown]
# ### 3.1.6 funded_amnt_inv

# %%
loan_data.funded_amnt_inv.value_counts()
# Out:
# 5000.000000     1309
# 10000.000000    1275
# 6000.000000     1200
# 12000.000000    1069
# 8000.000000      900
#                 ...
# 4944.213109        1
# 18400.281660       1
# 14659.820000       1
# 6294.151315        1
# 11808.924370       1
# Name: funded_amnt_inv, Length: 8205, dtype: int64

# %% [markdown]
# ### 3.1.7 term

# %%
loan_data.term.value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %% [markdown]
# ### 3.1.8 int_rate

# %%
loan_data.int_rate.value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 18.36%      1
# 16.96%      1
# 16.15%      1
# 16.01%      1
# 17.44%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
# remove % from values and convert to float
loan_data.int_rate = loan_data.int_rate.apply(lambda x: x[:-1] if x[-1] == '%' else x).astype(float)

# %% [markdown]
# ### 3.1.9 installment

# %%
loan_data.installment.value_counts()
# Out:
# 311.11     68
# 180.96     59
# 311.02     54
# 150.80     48
# 368.45     46
#            ..
# 1224.46     1
# 63.44       1
# 157.67      1
# 492.34      1
# 255.43      1
# Name: installment, Length: 15383, dtype: int64

# %% [markdown]
# ### 3.1.10 grade

# %%
loan_data.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %% [markdown]
# ### 3.1.11 sub_grade

# %%
loan_data.sub_grade.value_counts()
# Out:
# B3    2917
# A4    2886
# A5    2742
# B5    2704
# B4    2512
# C1    2136
# B2    2057
# C2    2011
# B1    1830
# A3    1810
# C3    1529
# A2    1508
# D2    1348
# C4    1236
# C5    1186
# D3    1173
# A1    1139
# D4     981
# D1     931
# D5     874
# E1     763
# E2     656
# E3     553
# E4     454
# E5     416
# F1     329
# F2     249
# F3     185
# F4     168
# F5     118
# G1     104
# G2      78
# G4      56
# G3      48
# G5      30
# Name: sub_grade, dtype: int64

# %% [markdown]
# ### 3.1.12 emp_length

# %%
loan_data.emp_length.value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %% [markdown]
# ### 3.1.13 home_ownership

# %%
loan_data.home_ownership.value_counts()
# Out:
# RENT        18899
# MORTGAGE    17659
# OWN          3058
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %% [markdown]
# ### 3.1.14 annual_inc

# %%
loan_data.annual_inc.value_counts()
# Out:
# 60000.0    1505
# 50000.0    1057
# 40000.0     876
# 45000.0     830
# 30000.0     825
#            ...
# 56820.0       1
# 45314.0       1
# 53913.0       1
# 62880.0       1
# 27376.0       1
# Name: annual_inc, Length: 5318, dtype: int64

# %% [markdown]
# ### 3.1.15 verifiction status

# %%
loan_data.verification_status.value_counts()
# Out:
# Not Verified       16921
# Verified           12809
# Source Verified     9987
# Name: verification_status, dtype: int64

# %% [markdown]
# ### 3.1.16 loan_status
#
# This is the target variable that decides if it's a good/bad loan

# %%
loan_data.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
# loan_status with value 'Current' are neither fully paid not defaulted, so removing rows with loan_status Current.
loan_data = loan_data[loan_data.loan_status != 'Current']

# %% [markdown]
# ### 3.1.17 url

# %%
(loan_data.url.value_counts() > 1).sum()
# Out:
# 0

# %%
# This is a unique url and doesn't impact the analysis. So this column can be removed
loan_data.drop(columns=['url'], inplace=True)

# %% [markdown]
# ### 3.1.18 desc

# %%
loan_data.desc.value_counts()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       209
# Debt Consolidation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      8
# Camping Membership                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      6
# credit card consolidation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3
# credit card debt consolidation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
#   Borrower added on 04/26/11 > I'm getting married on Sunday, May 29th.  I can't wait to start my new life with my lovely bride!  I am in need of last minute cash. I thank you in advance for supporting me. I am planning to pay off in 18-24 months max. Thanks again!<br/>                                                                                                                                                                                                                                                                                                                                                                          1
#   Borrower added on 04/27/11 > I'm a successful, self-employed music teacher... the only catch is that I didn't realize last year that I needed to be making estimated tax payments, so now I'm really behind with the IRS!  This loan will help me make the IRS happy immediately, while making my payments fit easily into my monthly budget (which the IRS' payment plans would not allow).  I look forward to making my estimated payments from now on so I'm never in this position again!<br/><br/>I love that I'll be paying interest into your pocket, instead of giving it all to some evil bank. Thank you for considering my loan.<br/>      1
#   Borrower added on 04/27/11 > Just cleaning up some debt and putting it in one payment.<br/> Borrower added on 04/27/11 > Would like to be debt free in 5 years.<br/>Mortgage payment is $660<br/>Credit Cards have $14,000 with a minimum of $350<br/>No car payment<br/>                                                                                                                                                                                                                                                                                                                                                                             1
#   Borrower added on 04/28/11 > We intend to use this money to purchase a used cruising sailboat. We have half of the needed total in hand; we don't want to miss out on a purchase opportunity while the spring buying season is active. Thanks to all our investors!  :-)<br/> Borrower added on 04/28/11 > I am an ardent sailor and this will be my third, and largest boat. I owned the two previous boats for about 5 years each. I hope to own this one considerably longer!<br/>                                                                                                                                                                 1
# I plan to consolidate over $7,000 of debt: a combination of credit cards and student loans.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: desc, Length: 25803, dtype: int64

# %%
# This is just a description and doesn't impact the analysis. So this column can be removed
loan_data.drop(columns=['desc'], inplace=True)

# %% [markdown]
# ### 3.1.19 purpose

# %%
loan_data.purpose.value_counts()
# Out:
# debt_consolidation    18055
# credit_card            5027
# other                  3865
# home_improvement       2875
# major_purchase         2150
# small_business         1754
# car                    1499
# wedding                 926
# medical                 681
# moving                  576
# vacation                375
# house                   367
# educational             325
# renewable_energy        102
# Name: purpose, dtype: int64

# %% [markdown]
# ### 3.1.20 title

# %%
loan_data.title.value_counts()
# Out:
# Debt Consolidation           2090
# Debt Consolidation Loan      1620
# Personal Loan                 641
# Consolidation                 491
# debt consolidation            478
#                              ...
# Murray Loan                     1
# Need debt consolidation!        1
# freedom2                        1
# DAVE WEDDING                    1
# JAL Loan                        1
# Name: title, Length: 19297, dtype: int64

# %% [markdown]
# ### 3.1.21 zip_code

# %%
loan_data.zip_code.value_counts()
# Out:
# 100xx    583
# 945xx    531
# 112xx    502
# 606xx    493
# 070xx    455
#         ...
# 463xx      1
# 381xx      1
# 592xx      1
# 414xx      1
# 469xx      1
# Name: zip_code, Length: 822, dtype: int64

# %% [markdown]
# ### 3.1.22 addr_state

# %%
loan_data.addr_state.value_counts()
# Out:
# CA    6949
# NY    3698
# FL    2781
# TX    2659
# NJ    1790
# IL    1478
# PA    1468
# VA    1369
# GA    1359
# MA    1297
# OH    1178
# MD    1023
# AZ     849
# WA     818
# CO     766
# NC     750
# CT     726
# MI     704
# MO     670
# MN     605
# NV     479
# SC     459
# WI     440
# AL     435
# OR     435
# LA     427
# KY     311
# OK     287
# KS     255
# UT     252
# AR     235
# DC     211
# RI     194
# NM     183
# WV     172
# NH     166
# HI     166
# DE     113
# MT      83
# WY      80
# AK      78
# SD      62
# VT      53
# MS      19
# TN      17
# IN       9
# ID       6
# IA       5
# NE       5
# ME       3
# Name: addr_state, dtype: int64

# %% [markdown]
# ### 3.1.23 dti

# %%
loan_data.dti.value_counts()
# Out:
# 0.00     178
# 12.00     46
# 18.00     45
# 19.20     39
# 13.20     39
#         ...
# 28.95      1
# 25.85      1
# 25.77      1
# 27.20      1
# 25.43      1
# Name: dti, Length: 2853, dtype: int64

# %% [markdown]
# ### 3.1.24 mths_since_last_delinq

# %%
loan_data.mths_since_last_delinq.value_counts()
# Out:
# 0.0      443
# 15.0     244
# 23.0     243
# 30.0     243
# 24.0     236
#         ...
# 107.0      1
# 85.0       1
# 97.0       1
# 95.0       1
# 115.0      1
# Name: mths_since_last_delinq, Length: 95, dtype: int64

# %% [markdown]
# ### 3.1.25 pub_rec_bankruptencies

# %%
loan_data.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    36238
# 1.0     1637
# 2.0        5
# Name: pub_rec_bankruptcies, dtype: int64

# %% [markdown]
# ### 3.2 Verify data frame

# %%
loan_data.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           4975.0   36 months     10.65       162.87
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 2       2400         2400           2400.0   36 months     15.96        84.33
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 5       5000         5000           5000.0   36 months      7.90       156.46
#
#   grade sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0     B        B2  10+ years           RENT     24000.0            Verified
# 1     C        C4   < 1 year           RENT     30000.0     Source Verified
# 2     C        C5  10+ years           RENT     12252.0        Not Verified
# 3     C        C1  10+ years           RENT     49200.0     Source Verified
# 5     A        A4    3 years           RENT     36000.0     Source Verified
#
#    loan_status         purpose                                  title  \
# 0   Fully Paid     credit_card                               Computer
# 1  Charged Off             car                                   bike
# 2   Fully Paid  small_business                   real estate business
# 3   Fully Paid           other                               personel
# 5   Fully Paid         wedding  My wedding loan I promise to pay back
#
#   zip_code addr_state    dti  mths_since_last_delinq  pub_rec_bankruptcies
# 0    860xx         AZ  27.65                     NaN                   0.0
# 1    309xx         GA   1.00                     NaN                   0.0
# 2    606xx         IL   8.72                     NaN                   0.0
# 3    917xx         CA  20.00                    35.0                   0.0
# 5    852xx         AZ  11.20                     NaN                   0.0

# %%
loan_data.shape
# Out:
# (38577, 20)

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   loan_amnt               38577 non-null  int64
#  1   funded_amnt             38577 non-null  int64
#  2   funded_amnt_inv         38577 non-null  float64
#  3   term                    38577 non-null  object
#  4   int_rate                38577 non-null  float64
#  5   installment             38577 non-null  float64
#  6   grade                   38577 non-null  object
#  7   sub_grade               38577 non-null  object
#  8   emp_length              37544 non-null  object
#  9   home_ownership          38577 non-null  object
#  10  annual_inc              38577 non-null  float64
#  11  verification_status     38577 non-null  object
#  12  loan_status             38577 non-null  object
#  13  purpose                 38577 non-null  object
#  14  title                   38566 non-null  object
#  15  zip_code                38577 non-null  object
#  16  addr_state              38577 non-null  object
#  17  dti                     38577 non-null  float64
#  18  mths_since_last_delinq  13672 non-null  float64
#  19  pub_rec_bankruptcies    37880 non-null  float64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 6.2+ MB

# %% [markdown]
# ## 3.3 Plots

# %%
def plot_numerical_percentage(col_name, x_name, bins_val = 10):
    plt.xticks(rotation = 90)
    df = loan_data
    bucket_col = x_name
    percent_col = "Charged Off" + " Percentage"
    df[bucket_col] = pd.cut(df[col_name], bins=bins_val)
    df = pd.pivot_table(data=df, index=bucket_col, columns="loan_status", values=col_name, aggfunc = np.count_nonzero, fill_value = 0)
    df[percent_col] = (df['Charged Off'] / (df['Charged Off'] + df['Fully Paid'])) * 100

    sns.barplot(x=df.index, y=df[percent_col])
    plt.show()

# %%
def plot_numerical(col_name, x_name, bins_val = 10):
    plt.figure(figsize = (10, 4))
    
    plt.subplot(1, 2, 1)
    sns.boxplot(loan_data.loan_status, loan_data[col_name])
    
    plt.subplot(1, 2, 2)
    plot_numerical_percentage(col_name, x_name, bins_val)

    plt.show()

# %%
def plot_categorical_percentage(col_name, x_name):
    plt.xticks(rotation = 90)
    df = loan_data
    percent_col = "Charged Off" + " Percentage"
    df = pd.pivot_table(data=df, index=col_name, columns="loan_status", values='loan_amnt', aggfunc = np.count_nonzero, fill_value = 0)
    df[percent_col] = (df['Charged Off'] / (df['Charged Off'] + df['Fully Paid'])) * 100

    ax = sns.barplot(x=df.index, y=df[percent_col])
    ax.set(xlabel=x_name)
    plt.show()

# %%
def plot_categorical(col_name, x_name):
    data = loan_data[[col_name, 'loan_status']]
    data['count'] = data[col_name]
    data_pivot = pd.pivot_table(data, values='count', index=col_name, columns='loan_status', aggfunc='count')
    data_pivot.plot(kind="bar", stacked="True")
    
    plt.show()

    plot_categorical_percentage(col_name, x_name)

# %% [markdown]
# ### loan_amnt vs loan_status
#
#   - Charged Off percent increases with loan_amnt

# %%
plot_numerical('loan_amnt', "Loan Amount", 10)

# %% [markdown]
# ### term vs loan_status
#  - Charged Off percent is considerably higher for term '60 months'

# %%
plot_categorical('term', 'Loan Term')

# %% [markdown]
# ### int_rate vs loan_status
# - Charged Off percent increases with interest rate

# %%
plot_numerical('int_rate', 'Interest Rate')

# %% [markdown]
# ### installment vs loan_status

# %%
plot_numerical('installment', 'Installment')

# %% [markdown]
# ### grade vs loan_status
#  - Number of Charged Off loans is more for grades B, C and D
#  - Percentage of Charged Off loans increases as grades go up

# %%
plot_categorical('grade', 'Grade')

# %% [markdown]
# ### sub_grade vs loan_status
# - Number of Charged Off loans is more for sub grades B2,B3,B4,B5, C1,C2,C3,C4 and D2,D3,D4,D5
# - Percentage of Charged Off loans increases as sub grades go up

# %%
plot_categorical('sub_grade', 'Sub Grade')

# %% [markdown]
# ### home_ownership vs loan_status
# - Number of Charged Off loans is more when home ownership is 'Mortgage' or 'Rent'
# - Percentage of Charged Off loans is high when home ownership is 'Other'

# %%
plot_categorical('home_ownership', 'Home Ownership')

# %% [markdown]
# ### emp_length vs loan_status

# %%
plot_categorical('emp_length', 'Employment Length')

# %% [markdown]
# ### annual_inc vs loan_status
#  - 25, 50 and 75 Percentile values are low for charged off loans. This indicates as annual income decreases, chances of charged off loans increases.
#  - Percentage of Charged Off loans increases as annual income decrease.

# %%
plot_numerical('annual_inc', 'Annual Income')

# %%
# Box plots are not proper due to outliers. Followed trial and error and removed all outliers above 96 percentile.
loan_data = loan_data[loan_data.annual_inc < loan_data.annual_inc.quantile(.96)]

# %%
plot_numerical('annual_inc', 'Annual Income')

# %% [markdown]
# ### verification_status vs loan_status

# %%
plot_categorical('verification_status', 'Verification Status')

# %% [markdown]
# ### purpose vs loan_status
# - Number of Charged Off loans is more for when purpose is 'debt_consolidation', 'credit_card' or 'other'
# - Percentage of Charged Off loans high for small business, renewable energy and educational.

# %%
plot_categorical('purpose', 'Purpose')

# %% [markdown]
# ### dti vs loan_status
# - Percentage of Charged Off loans increases as debt to income ratio goes up

# %%
plot_numerical('dti', 'Debt To Income Ratio', 3)

# %% [markdown]
# ### mths_since_last_delinq vs loan_status

# %%
plot_numerical('mths_since_last_delinq', 'Months Since Last Delinq',4)

# %% [markdown]
# ### pub_rec_bankruptencies vs loan_status

# %%
plot_categorical('pub_rec_bankruptcies', 'pub_rec_bankruptcies')

# %% [markdown]
# ### addr_state vs annual_inc, addr_state vs loan_amnt
#
#  - For state 'WY' number of Charged Off loans are very high

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
sns.barplot(data =loan_data,x='annual_inc', y='addr_state', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)

plt.subplot(1,2,2)
sns.barplot(data =loan_data,x='loan_amnt', y='addr_state', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### **Countplot addr_state**

# %% [markdown]
# ### addr_state

# %%
plt.figure(figsize=(15,10))
sns.countplot(y='addr_state', data=loan_data, hue='loan_status')
plt.show()

# %% [markdown]
# ### grade/term/home_ownership/addr_state/purpose with annual_inc/loan_amount and hue as loan_status

# %% [markdown]
# ### Annual Income vs Purpose

# %%
plt.figure(figsize=(15,10))
sns.barplot(data =loan_data,x='annual_inc', y='purpose', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### Annual Income vs grade

# %%
plt.figure(figsize=(10,10))
sns.barplot(data =loan_data,x='annual_inc', y='grade', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### Annual Income vs term

# %%
sns.barplot(data =loan_data,x='annual_inc', y='term', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### Annual Income vs home_ownership

# %%
sns.barplot(data =loan_data,x='annual_inc', y='home_ownership', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### loan_amnt vs Purpose

# %%
plt.figure(figsize=(15,10))
sns.barplot(data =loan_data,x='loan_amnt', y='purpose', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### loan_amnt vs grade

# %%
plt.figure(figsize=(10,10))
sns.barplot(data =loan_data,x='loan_amnt', y='grade', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### loan_amnt vs term

# %%
sns.barplot(data =loan_data,x='loan_amnt', y='term', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ### loan_amnt vs home_ownership

# %%
sns.barplot(data =loan_data,x='loan_amnt', y='home_ownership', hue ='loan_status', hue_order=['Charged Off', 'Fully Paid'], ci=None)
plt.show()

# %% [markdown]
# ## Pair Plot

# %%
pair_plt = loan_data[['loan_amnt' ,'annual_inc', 'term','dti','int_rate','loan_status']]
plt.figure(figsize=(15,10))
sns.pairplot(pair_plt, hue = 'loan_status')
plt.show()

# %% [markdown]
#  - Charged off loans are more when annual income is more
#  - Charged off loans are more when int_rate is high

# %% [markdown]
# ## 3.2 Correlation Analysis

# %%
loan_data.corr()
# Out:
#                         loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                1.000000     0.981958         0.936851  0.291974
# funded_amnt              0.981958     1.000000         0.954807  0.296914
# funded_amnt_inv          0.936851     0.954807         1.000000  0.289537
# int_rate                 0.291974     0.296914         0.289537  1.000000
# installment              0.931542     0.957219         0.902842  0.269807
# annual_inc               0.403162     0.398989         0.381982  0.054509
# dti                      0.088930     0.088108         0.095907  0.112057
# mths_since_last_delinq   0.021754     0.021533         0.078246 -0.053157
# pub_rec_bankruptcies    -0.030340    -0.031302        -0.035902  0.086679
#
#                         installment  annual_inc       dti  \
# loan_amnt                  0.931542    0.403162  0.088930
# funded_amnt                0.957219    0.398989  0.088108
# funded_amnt_inv            0.902842    0.381982  0.095907
# int_rate                   0.269807    0.054509  0.112057
# installment                1.000000    0.398374  0.077752
# annual_inc                 0.398374    1.000000 -0.075518
# dti                        0.077752   -0.075518  1.000000
# mths_since_last_delinq     0.007193   -0.003961  0.067410
# pub_rec_bankruptcies      -0.027645   -0.008200  0.004378
#
#                         mths_since_last_delinq  pub_rec_bankruptcies
# loan_amnt                             0.021754             -0.030340
# funded_amnt                           0.021533             -0.031302
# funded_amnt_inv                       0.078246             -0.035902
# int_rate                             -0.053157              0.086679
# installment                           0.007193             -0.027645
# annual_inc                           -0.003961             -0.008200
# dti                                   0.067410              0.004378
# mths_since_last_delinq                1.000000              0.024122
# pub_rec_bankruptcies                  0.024122              1.000000

# %% [markdown]
# # 4 Recommendations

# %% [markdown]
# **Loan Amount:**
#
# Possibility of loan being Charged Off increases as the loan amount goes high.

# %%
plot_numerical_percentage('loan_amnt', 'Loan Amount')

# %% [markdown]
# **Loan Term:**
#
# Charged Off percent is considerably higher for term '60 months'

# %%
plot_categorical_percentage('term', 'Loan Term')

# %% [markdown]
# **Interest Rate:**
#
# Charged Off percent increases with interest rate.
#
# Scatter plot between int rate and loan amount, we can observe that the number of defaulters increases as interest rate increases, irrespective of the loan amount.
#
# People pay off loans on time when interest and loan amount are low.

# %%
plot_numerical_percentage('int_rate', 'Interest Rate')

# %%
scatter_plt = loan_data[['loan_amnt' ,'int_rate','loan_status']]
sns.scatterplot(data=scatter_plt, x="loan_amnt", y="int_rate", hue="loan_status")
plt.show()

# %% [markdown]
#  **Groups & Sub Groups:**
#
#   Percentage of Charged Off loans increases as grades and subgrades go up

# %%
plot_categorical_percentage('grade', 'Grade')

# %%
plot_categorical_percentage('sub_grade', 'Sub Grade')

# %% [markdown]
# **Home Ownership :**
#
# Chances of Charged of is slightly higher when Home Owner ship falls in 'Other'.

# %%
plot_categorical_percentage('home_ownership', 'Home Ownership')

# %% [markdown]
# **Annual Income :**
#
# Percentage of Charged Off loans increases as annual income decrease.

# %%
plot_numerical_percentage('annual_inc', 'Annual Income')

# %% [markdown]
# **Purpose :**
#
# Charged off loans is significantly high when purpose of loan is small business

# %%
plot_categorical_percentage('purpose', 'Purpose')

# %% [markdown]
# **Debt to Income Ratio :**
#
# As the Debt to Income ratio goes up, percentage of Charged Off loans also increases.

# %%
plot_numerical_percentage('dti', 'Debt To Income Ratio')
